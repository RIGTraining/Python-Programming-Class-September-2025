# %% [markdown]
# <div _ngcontent-ng-c2785906616="" class="markdown markdown-main-panel enable-updated-hr-color" id="model-response-message-contentr_afbc18ff2184ec42" dir="ltr" style="--animation-duration: 400ms; --fade-animation-function: linear;"><p>Python ဟာ ကွန်ပြူတာ ပရိုဂရမ်ရေးသားရာမှာ အသုံးပြုတဲ့ ဘာသာစကားတစ်ခု ဖြစ်ပါတယ်။ သူ့ကို <b>Guido van Rossum</b> က ၁၉၉၁ ခုနှစ်မှာ စတင်ဖန်တီးခဲ့တာပါ။</p><hr><p></p><h4 style="color:yellow;">Python ဘာကြောင့် လူကြိုက်များသလဲ</h4><p></p><ul><li><p><b>လေ့လာရလွယ်ကူခြင်း</b></p><ul><li><p>Python ရဲ့ Syntax (ရေးထုံး) တွေက ရိုးရှင်းပြီး အင်္ဂလိပ်စကားနဲ့ နီးစပ်လို့ ပရိုဂရမ်အသစ်စလေ့လာသူတွေအတွက် အထူးသင့်တော်ပါတယ်။</p></li><li><p>တခြား ပရိုဂရမ်းမင်းဘာသာစကားတွေလို Code (ကုတ်) အများကြီး ရေးစရာမလိုဘဲ အလုပ်တစ်ခုကို ပြီးမြောက်အောင် လုပ်နိုင်ပါတယ်။</p></li></ul></li><li><p><b>ဘက်စုံအသုံးပြုနိုင်ခြင်း (Versatility)</b></p><ul><li><p>Python ကို နယ်ပယ်အမျိုးမျိုးမှာ အသုံးချနိုင်ပါတယ်။</p><ul><li><p><b>ဝက်ဘ်ဆိုက်တည်ဆောက်ခြင်း (Web Development)</b>: Django နဲ့ Flask လို Framework တွေသုံးပြီး ဝက်ဘ်ဆိုက်တွေ ဖန်တီးနိုင်ပါတယ်။</p></li><li><p><b>ဒေတာသိပ္ပံ (Data Science) နဲ့ စက်ရုပ်သင်ယူမှု (Machine Learning)</b>: Pandas, NumPy, Scikit-learn လို Library တွေရှိလို့ ဒေတာတွေကို ခွဲခြမ်းစိတ်ဖြာတာ၊ Machine Learning Model တွေတည်ဆောက်တာ စတာတွေ လုပ်နိုင်ပါတယ်။</p></li><li><p><b>ဆော့ဖ်ဝဲလ်တည်ဆောက်ခြင်း (Software Development)</b>: Desktop Application တွေ ရေးသားနိုင်ပါတယ်။</p></li><li><p><b>ဂိမ်းဖန်တီးခြင်း (Game Development)</b>: Pygame လို Library တွေနဲ့ ဂိမ်းတွေဖန်တီးနိုင်ပါတယ်။</p></li><li><p><b>အလိုအလျောက်လုပ်ဆောင်ခြင်း (Automation)</b>: ကွန်ပြူတာနဲ့ ပတ်သက်တဲ့ ထပ်တလဲလဲလုပ်ရတဲ့ အလုပ်တွေကို Automate လုပ်ဖို့ Python Script တွေ ရေးနိုင်ပါတယ်။</p></li></ul></li></ul></li><li><p><b>Community အင်အားကြီးမားခြင်း</b></p><ul><li><p>Python ကို အသုံးပြုသူတွေ အများကြီးရှိတာကြောင့် အွန်လိုင်းမှာ အကူအညီနဲ့ သင်ခန်းစာတွေ အလွယ်တကူ ရှာဖွေနိုင်ပါတယ်။</p></li><li><p>ပြဿနာတစ်ခုခု ကြုံလာရင်လည်း Stack Overflow လို ဖိုရမ်တွေမှာ အဖြေရှာနိုင်ပါတယ်။</p></li></ul></li></ul><hr><p></p><h4 style="color:yellow">အခြေခံအချက်များ</h4><p></p><ul><li><p><b>Code ရဲ့ ပုံစံ</b></p><ul><li><p>Python ဟာ Indentation (ကုတ်ရဲ့ ရှေ့မှာ ချန်ထားတဲ့ နေရာလွတ်) ကို အသုံးပြုပြီး Code Block တွေကို ခွဲခြားပါတယ်။ ဒါကြောင့် Code တွေက ဖတ်ရလွယ်ပြီး သပ်ရပ်ပါတယ်။</p><response-element class="" ng-version="0.0.0-PLACEHOLDER"><!----><!----><!----><!----><code-block _nghost-ng-c2641055084="" class="ng-tns-c2641055084-22 ng-star-inserted" style=""><!----><!----><div _ngcontent-ng-c2641055084="" class="code-block ng-tns-c2641055084-22 ng-animate-disabled ng-trigger ng-trigger-codeBlockRevealAnimation" jslog="223238;track:impression,attention;BardVeMetadataKey:[[&quot;r_afbc18ff2184ec42&quot;,&quot;c_314435b8227dbb30&quot;,null,&quot;rc_534faa4659a42714&quot;,null,null,&quot;my&quot;,null,1,null,null,1,0]]" data-hveid="0" decode-data-ved="1" data-ved="0CAAQhtANahcKEwjWt_zP_r2PAxUAAAAAHQAAAAAQEw" style="display: block;"><div _ngcontent-ng-c2641055084="" class="code-block-decoration header-formatted gds-title-s ng-tns-c2641055084-22 ng-star-inserted" style=""><span _ngcontent-ng-c2641055084="" class="ng-tns-c2641055084-22">Python</span><div _ngcontent-ng-c2641055084="" class="buttons ng-tns-c2641055084-22 ng-star-inserted"><button _ngcontent-ng-c2641055084="" aria-label="Copy code" mat-icon-button="" mattooltip="Copy code" class="mdc-icon-button mat-mdc-icon-button mat-mdc-button-base mat-mdc-tooltip-trigger copy-button ng-tns-c2641055084-22 mat-unthemed ng-star-inserted" mat-ripple-loader-uninitialized="" mat-ripple-loader-class-name="mat-mdc-button-ripple" mat-ripple-loader-centered="" jslog="179062;track:generic_click,impression;BardVeMetadataKey:[[&quot;r_afbc18ff2184ec42&quot;,&quot;c_314435b8227dbb30&quot;,null,&quot;rc_534faa4659a42714&quot;,null,null,&quot;my&quot;,null,1,null,null,1,0]];mutable:true"><span class="mat-mdc-button-persistent-ripple mdc-icon-button__ripple"></span><mat-icon _ngcontent-ng-c2641055084="" role="img" fonticon="content_copy" class="mat-icon notranslate google-symbols mat-ligature-font mat-icon-no-color" aria-hidden="true" data-mat-icon-type="font" data-mat-icon-name="content_copy"></mat-icon><span class="mat-focus-indicator"></span><span class="mat-mdc-button-touch-target"></span></button><!----><!----></div><!----></div><!----><div _ngcontent-ng-c2641055084="" class="formatted-code-block-internal-container ng-tns-c2641055084-22"><div _ngcontent-ng-c2641055084="" class="animated-opacity ng-tns-c2641055084-22"><pre _ngcontent-ng-c2641055084="" class="ng-tns-c2641055084-22"><code _ngcontent-ng-c2641055084="" role="text" data-test-id="code-content" class="code-container formatted ng-tns-c2641055084-22"><span class="hljs-comment"># Python ရဲ့ ရေးထုံးပုံစံ ဥပမာ</span>
# <span class="hljs-keyword">if</span> <span class="hljs-number">5</span> &gt; <span class="hljs-number">2</span>:
#     print(<span class="hljs-string">"5 is greater than 2"</span>)
# </code></pre><!----><!----><!----></div></div></div><!----><!----><!----></code-block><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----><!----></response-element></li></ul></li><li><p><b>Interpreted Language ဖြစ်ခြင်း</b></p><ul><li><p>Python Code တွေကို Compiler နဲ့ Compile လုပ်စရာမလိုဘဲ Interpreter နဲ့ တိုက်ရိုက် Run လို့ရပါတယ်။ ဒါကြောင့် Code တစ်ခုခု ပြောင်းလိုက်တိုင်း Compile ပြန်လုပ်စရာမလိုလို့ အချိန်ကုန်သက်သာပါတယ်။</p></li></ul></li><li><p><b>Library တွေ ပေါများခြင်း</b></p><ul><li><p>Python မှာ အမျိုးအစားစုံတဲ့ အသင့်သုံး Library တွေ အများကြီးရှိပါတယ်။ ဒီ Library တွေကို အသုံးပြုပြီး ကိုယ့်ရဲ့ ပရိုဂရမ်ကို အစကနေ ပြန်ရေးစရာမလိုဘဲ အလွယ်တကူ တည်ဆောက်နိုင်ပါတယ်။</p></li></ul></li></ul></div>

# %% [markdown]
# <h4 style="color:yellow;"><span>Python သုံးပြီး ဘာတွေလုပ်နိုင်လဲ？</span></h4>
# <ul><li><p class="ds-markdown-paragraph"><strong><span>Website Development</span></strong><span> - Django, Flask frameworks တွေနဲ့</span></p></li><li><p class="ds-markdown-paragraph"><strong><span>Data Analysis</span></strong><span> - Pandas, NumPy libraries တွေနဲ့</span></p></li><li><p class="ds-markdown-paragraph"><strong><span>Machine Learning</span></strong><span> - TensorFlow, PyTorch, Scikit-Learn တွေနဲ့</span></p></li><li><p class="ds-markdown-paragraph"><strong><span>Automation</span></strong><span> - Repetitive tasks တွေကို automate လုပ်ဖို့</span></p></li><li><p class="ds-markdown-paragraph"><strong><span>Game Development</span></strong><span> - Pygame သုံးပြီး game ရေးနိုင်တယ်</span></p></li></ul>
